# %% [markdown]
# 1.
# ![stat.png](attachment:stat.png)

# %% [markdown]
# b)
# P(X=0) = (1^0) *(e ^ -1)/0! = 0.37

# %% [markdown]
# c)
# 1-P(X=0)-P(X=1) = 1 - e^-1 - e^-1 = 1-2e^-1 = 0.26

# %% [markdown]
# 2.
# P(last passenger in line gets to sit in his or her assigned seat) = 1/2
