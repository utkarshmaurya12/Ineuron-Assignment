# %%
1.
Enclosing a list comprehension in square brackets gives a list whereas enclosing it in parentheses gives a tuple.

# %%
2.
Iterators are used to iterate or convert other objects to iterator while generators are used in loops to generate an iterator
by returning all the values in the loop.

# %%
3.
If a function contains at least one yield statement, it becomes a generator function.

# %%
4.
Yield is a keyword in Python that is used to return from a function without destroying the states of its local variable.

# %%
5.
The map function takes an expression and an Iterable. The output will be an Iterable object where the expression will work on 
each element of the given Iterable.
Python List Comprehension is used for creating a list where each element is generated by applying a simple formula on the
given list.  
List comprehension is more concise and easier to read as compared to map.
List comprehension are used when a list of results is required as map only returns a map object and does not return any list.
Both list and map can be used to give a list of values.
